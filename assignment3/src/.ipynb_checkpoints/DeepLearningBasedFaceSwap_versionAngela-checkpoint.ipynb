# %% [markdown]
# # Deep Learning Based Face Swap Tutorial
#
# April 23, 2021. v0.2.0

# %% [markdown]
# # Intro
#
# Generating images or videos by manipulating facial attributes (i.e. face reenactment and swapping) has gained a lot of attention in recent years due to their broad range of computer vision and multimedia applications such as video dubbing, gaze correction, actor capturing, and virtual avatar creation. Imagine, old Mark Hamill could act as a young Luke Skywalker, or a stuntman acting as Daniel Craig. In this tutorial, you will play with a face swapping pipeline based on 2D-to-3D reconstruction.
#
# The task of face reenactment is to change attribute of a face image (i.e. pose, expression or light), while *face swapping* is focused on changing face identity of an image while keeping other attributes (pose, expression and background) the same. Face identity can be defined as a set of attributes which identifies a person. It can range from a skin / eye colors to face geometry and expression. Ignoring geometrical changes and lighting condition, one can approximate facial identity purely by a texture of the face region.

# %% [markdown]
# # Environment preparation
#
# Before everything, please add a shortcut to this Google Drive directory: https://drive.google.com/drive/folders/1EEdqNgK8xN-gqJO5-NLv4PGH5_dU7zna?usp=sharing
#
# Download BFM 2009 model from here https://faces.dmi.unibas.ch/bfm/index.php?nav=1-2&id=downloads (BFM 2009 used in this part of the assignment is different from BFM 2017 used in the other part).

# %%
## Mounts Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow==1.13.1
# !pip install tensorflow-gpu==1.13.1
# Out:
# Mounted at /content/gdrive
# Found existing installation: tensorflow 2.8.0+zzzcolab20220506162203
# Uninstalling tensorflow-2.8.0+zzzcolab20220506162203:
#   Successfully uninstalled tensorflow-2.8.0+zzzcolab20220506162203
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.13.1
#   Downloading tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6 MB)
#      |████████████████████████████████| 92.6 MB 1.2 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.46.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.5.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.37.1)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.0.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 37.7 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.8.1)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.7 MB/s
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
#      |████████████████████████████████| 367 kB 56.8 MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.21.6)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (3.17.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.2.0)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.13.1) (1.5.2)
# Installing collected packages: mock, tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.13.1 which is incompatible.
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.13.1
#   Downloading tensorflow_gpu-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (345.0 MB)
#      |████████████████████████████████| 345.0 MB 3.5 kB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.5.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.21.6)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.46.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.8.1)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.37.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.2.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (4.0.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.13.1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.13.1

# %%
# !cp /content/gdrive/MyDrive/CV2/cv2_2021_assignment3.zip . 
# !unzip cv2_2021_assignment3.zip
# !mv Assignment3/cv2_2021_assignment3 .
# Out:
# Archive:  cv2_2021_assignment3.zip
#    creating: Assignment3/
#   inflating: __MACOSX/._Assignment3
#   inflating: Assignment3/Computer_Vision_2___Assignment_3__2D_to_3D__2021_.pdf
#   inflating: Assignment3/.DS_Store
#    creating: Assignment3/cv2_2021_assignment3/
#   inflating: __MACOSX/Assignment3/._cv2_2021_assignment3
#    creating: Assignment3/supplemental_code/
#   inflating: __MACOSX/Assignment3/._supplemental_code
#   inflating: Assignment3/cv2_2021_assignment3/texture_manip.py
#   inflating: Assignment3/cv2_2021_assignment3/LICENSE
#   inflating: Assignment3/cv2_2021_assignment3/requirements.txt
#    creating: Assignment3/cv2_2021_assignment3/BFM/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._BFM
#    creating: Assignment3/cv2_2021_assignment3/gan_blender_release/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._gan_blender_release
#    creating: Assignment3/cv2_2021_assignment3/images/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._images
#    creating: Assignment3/cv2_2021_assignment3/input/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._input
#    creating: Assignment3/cv2_2021_assignment3/texturing/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._texturing
#   inflating: Assignment3/cv2_2021_assignment3/preprocess_img.py
#    creating: Assignment3/cv2_2021_assignment3/network/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._network
#   inflating: Assignment3/cv2_2021_assignment3/face_swap.py
#    creating: Assignment3/cv2_2021_assignment3/annotation/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._annotation
#   inflating: Assignment3/cv2_2021_assignment3/face_tracker.py
#   inflating: Assignment3/cv2_2021_assignment3/readme.md
#    creating: Assignment3/cv2_2021_assignment3/adapters/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._adapters
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/
#   inflating: __MACOSX/Assignment3/cv2_2021_assignment3/._tf_mesh_renderer
#   inflating: Assignment3/cv2_2021_assignment3/face_decoder.py
#   inflating: Assignment3/cv2_2021_assignment3/fio.py
#   inflating: Assignment3/cv2_2021_assignment3/load_data.py
#   inflating: Assignment3/supplemental_code/.DS_Store
#   inflating: Assignment3/supplemental_code/requirements.txt
#   inflating: Assignment3/supplemental_code/Landmarks68_model2017-1_face12_nomouth.anl
#   inflating: Assignment3/supplemental_code/README.md
#   inflating: Assignment3/supplemental_code/.gitignore
#   inflating: Assignment3/supplemental_code/supplemental_code.py
#   inflating: Assignment3/cv2_2021_assignment3/BFM/std_exp.txt
#   inflating: Assignment3/cv2_2021_assignment3/BFM/select_vertex_id.mat
#   inflating: Assignment3/cv2_2021_assignment3/BFM/BFM_front_idx.mat
#   inflating: Assignment3/cv2_2021_assignment3/BFM/facemodel_info.mat
#   inflating: Assignment3/cv2_2021_assignment3/BFM/BFM_exp_idx.mat
#   inflating: Assignment3/cv2_2021_assignment3/BFM/similarity_Lm3D_all.mat
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/discriminators_pix2pix.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/vgg.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/SwappedDataset.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/train_blender.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/res_unet.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/gan_loss.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/utils.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/vgg_loss.py
#   inflating: Assignment3/cv2_2021_assignment3/gan_blender_release/img_utils.py
#   inflating: Assignment3/cv2_2021_assignment3/images/alignment.png
#   inflating: Assignment3/cv2_2021_assignment3/images/albedo.png
#   inflating: Assignment3/cv2_2021_assignment3/images/example.gif
#   inflating: Assignment3/cv2_2021_assignment3/images/lm3d.png
#   inflating: Assignment3/cv2_2021_assignment3/images/camera.png
#   inflating: Assignment3/cv2_2021_assignment3/images/extreme.png
#   inflating: Assignment3/cv2_2021_assignment3/images/lm5p.png
#   inflating: Assignment3/cv2_2021_assignment3/images/example.png
#   inflating: Assignment3/cv2_2021_assignment3/input/vd026.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000050.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd092.png
#   inflating: Assignment3/cv2_2021_assignment3/input/000033.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd051.png
#   inflating: Assignment3/cv2_2021_assignment3/input/000125.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd025.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015310.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015270.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000031.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000126.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015259.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd034.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015316.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000055.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000037.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd092.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000125.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd051.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000033.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000050.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd026.png
#   inflating: Assignment3/cv2_2021_assignment3/input/000126.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/015259.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd025.png
#   inflating: Assignment3/cv2_2021_assignment3/input/015310.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000031.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015270.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd034.png
#   inflating: Assignment3/cv2_2021_assignment3/input/015316.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000055.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000037.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd070.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000006.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd006.png
#   inflating: Assignment3/cv2_2021_assignment3/input/000007.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015384.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015309.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd102.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000002.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000114.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000007.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/000006.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/vd070.png
#   inflating: Assignment3/cv2_2021_assignment3/input/vd006.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/015384.jpg
#   inflating: Assignment3/cv2_2021_assignment3/input/015309.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/vd102.png
#   inflating: Assignment3/cv2_2021_assignment3/input/000114.txt
#   inflating: Assignment3/cv2_2021_assignment3/input/000002.jpg
#   inflating: Assignment3/cv2_2021_assignment3/texturing/mesh_renderer_texture.py
#   inflating: Assignment3/cv2_2021_assignment3/texturing/__init__.py
#   inflating: Assignment3/cv2_2021_assignment3/texturing/rasterize_triangles.py
#   inflating: Assignment3/cv2_2021_assignment3/network/blank.txt
#   inflating: Assignment3/cv2_2021_assignment3/annotation/000002._mesh.obj
#   inflating: Assignment3/cv2_2021_assignment3/adapters/FAN.py
#   inflating: Assignment3/cv2_2021_assignment3/adapters/__init__.py
#   inflating: Assignment3/cv2_2021_assignment3/adapters/DLIB.py
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/LICENSE
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/MANIFEST
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/camera_utils.py
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/README.md
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/setup.py
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/third_party/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.gitignore
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/VERSION
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/rasterize_triangles.py
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/data/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer.py
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/notebooks/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_utils.py
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/rasterize_triangles_test.py
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/mesh_renderer_test.py
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/third_party/lodepng.h
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/third_party/lodepng.cpp
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/config
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/objects/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/HEAD
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/hooks/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/index
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/packed-refs
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/data/.gitignore
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/notebooks/FirstCrack.ipynb
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/rasterize_triangles_grad.cc
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/rasterize_triangles_impl.cc
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/rasterize_triangles_impl.h
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/rasterize_triangles_op.cc
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/kernels/rasterize_triangles_impl_test.cc
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Simple_Triangle.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Simple_Tetrahedron.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Unlit_Cube_0.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Gray_Cube_0.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Gray_Cube_1.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Barycentrics_Cube.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/External_Triangle.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/BUILD
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Inside_Box.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Perspective_Corrected_Triangle.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Colored_Cube_0.png
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/mesh_renderer/test_data/Colored_Cube_1.png
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/objects/pack/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/objects/info/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/HEAD
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/heads/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/tags/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/remotes/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/objects/pack/pack-651e768144b9d206a93d9ded67eba8d893080bb7.pack
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/objects/pack/pack-651e768144b9d206a93d9ded67eba8d893080bb7.idx
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/heads/
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/remotes/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/heads/master
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/remotes/origin/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/heads/master
#    creating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/remotes/origin/
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/refs/remotes/origin/HEAD
#   inflating: Assignment3/cv2_2021_assignment3/tf_mesh_renderer/.git/logs/refs/remotes/origin/HEAD

# %% [markdown]
# Copying weights and metadata from Google Drive. Before running the code below, put ``01_MorphableModel.mat`` you have downloaded before into the Google Drive folder. If you have ``01_MorphableModel.mat`` somewhere else, you can change the path.

# %%
# !cp -v /content/gdrive/MyDrive/01_MorphableModel.mat cv2_2021_assignment3/BFM
# !cp -v /content/gdrive/MyDrive/CV2/Exp_Pca.bin cv2_2021_assignment3/BFM

# !mkdir -p cv2_2021_assignment3/network
# !cp -v /content/gdrive/MyDrive/CV2/FaceReconModel.pb cv2_2021_assignment3/network
# Out:
# '/content/gdrive/MyDrive/01_MorphableModel.mat' -> 'cv2_2021_assignment3/BFM/01_MorphableModel.mat'
# '/content/gdrive/MyDrive/CV2/Exp_Pca.bin' -> 'cv2_2021_assignment3/BFM/Exp_Pca.bin'
# '/content/gdrive/MyDrive/CV2/FaceReconModel.pb' -> 'cv2_2021_assignment3/network/FaceReconModel.pb'

# %% [markdown]
# Installing face analysis dependencies.

# %%
# Needed to generate the facial landmarks
# !pip install https://github.com/cmusatyalab/openface/archive/0.2.1.zip
# !pip install dlib
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 && bzip2 -d shape_predictor_68_face_landmarks.dat.bz2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/cmusatyalab/openface/archive/0.2.1.zip
#   Downloading https://github.com/cmusatyalab/openface/archive/0.2.1.zip
#      / 5.2 MB 3.2 MB/s
# Building wheels for collected packages: openface
#   Building wheel for openface (setup.py) ... done
#   Created wheel for openface: filename=openface-0.2.1-py3-none-any.whl size=13705 sha256=d74e06a7955776ce1f95571d5b554a3b1ffb5e75861bc54dcd6443c0147c2ef3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d9wdtwnp/wheels/ea/8c/e3/e2e038ffc4f8e404e730320b4569b1908a9fb2985838b090d9
# Successfully built openface
# Installing collected packages: openface
# Successfully installed openface-0.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dlib in /usr/local/lib/python3.7/dist-packages (19.18.0+zzzcolab20220513001918)
# --2022-05-27 15:16:30--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  50.4MB/s    in 1.2s
#
# 2022-05-27 15:16:32 (50.4 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]

# %% [markdown]
# Building other dependencies.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf

TF_LIB = tf.sysconfig.get_lib()

# !cp -v $TF_LIB/libtensorflow_framework.so.1 /usr/lib/
# !cd /usr/lib/ && ln -s libtensorflow_framework.so.1 libtensorflow_framework.so
# !cd /content/cv2_2021_assignment3/tf_mesh_renderer;\
  sed -i -r ':a;N;$!ba;s/def get_libraries\(self, ext\):(\n\s*)/def get_libraries(self, ext):\1return None\1/g' setup.py

# !cd /content/cv2_2021_assignment3/tf_mesh_renderer && python setup.py install
# Out:
# cp: cannot stat '/usr/local/lib/python3.7/dist-packages/tensorflow/libtensorflow_framework.so.1': No such file or directory
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'install_requires'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# copying mesh_renderer.py -> build/lib.linux-x86_64-3.7
# copying camera_utils.py -> build/lib.linux-x86_64-3.7
# copying rasterize_triangles.py -> build/lib.linux-x86_64-3.7
# running build_ext
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# building 'mesh_renderer_lib' extension
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/mesh_renderer
# creating build/temp.linux-x86_64-3.7/mesh_renderer/kernels
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include/external/nsync/public -I/usr/include/python3.7m -c mesh_renderer/kernels/rasterize_triangles_op.cc -o build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_op.o -std=c++11 -D_GLIBCXX_USE_CXX11_ABI=1
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include/external/nsync/public -I/usr/include/python3.7m -c mesh_renderer/kernels/rasterize_triangles_impl.cc -o build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_impl.o -std=c++11 -D_GLIBCXX_USE_CXX11_ABI=1
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include -I/usr/local/lib/python3.7/dist-packages/tensorflow/include/external/nsync/public -I/usr/include/python3.7m -c mesh_renderer/kernels/rasterize_triangles_grad.cc -o build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_grad.o -std=c++11 -D_GLIBCXX_USE_CXX11_ABI=1
# mesh_renderer/kernels/rasterize_triangles_grad.cc: In member function ‘virtual void tf_mesh_renderer::RasterizeTrianglesGradOp::Compute(tensorflow::OpKernelContext*)’:
# mesh_renderer/kernels/rasterize_triangles_grad.cc:144:48: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        for (unsigned int pixel_id = 0; pixel_id < image_height_ * image_width_;
#                                        ~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_op.o build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_impl.o build/temp.linux-x86_64-3.7/mesh_renderer/kernels/rasterize_triangles_grad.o -L/usr/local/lib -L/usr/local/lib/python3.7/dist-packages/tensorflow -o build/lib.linux-x86_64-3.7/mesh_renderer_lib.cpython-37m-x86_64-linux-gnu.so -ltensorflow_framework
# running install_lib
# copying build/lib.linux-x86_64-3.7/camera_utils.py -> /usr/local/lib/python3.7/dist-packages
# copying build/lib.linux-x86_64-3.7/mesh_renderer_lib.cpython-37m-x86_64-linux-gnu.so -> /usr/local/lib/python3.7/dist-packages
# copying build/lib.linux-x86_64-3.7/mesh_renderer.py -> /usr/local/lib/python3.7/dist-packages
# copying build/lib.linux-x86_64-3.7/rasterize_triangles.py -> /usr/local/lib/python3.7/dist-packages
# byte-compiling /usr/local/lib/python3.7/dist-packages/camera_utils.py to camera_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/mesh_renderer.py to mesh_renderer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/rasterize_triangles.py to rasterize_triangles.cpython-37.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.7/dist-packages/mesh_renderer-1.0.egg-info

# %% [markdown]
# # Implementation
#
# Given two images, foreground and background, the task of face swapping is to change identity of the background image into foreground while keeping all other attributes (pose, expression, environment etc.) to be the same.
#
# Below are preset foreground and background images. To play with other images, upload to the Google Drive folder first and change paths.

# %%
# %cd /content/cv2_2021_assignment3
# Out:
# /content/cv2_2021_assignment3

# %%
fg_path = "/content/gdrive/MyDrive/CV2/clinton.jpg"
bg_path = "/content/gdrive/MyDrive/CV2/trump.jpg"

# %%
import cv2
import dlib
import openface
import numpy as np

# %%
# Reading background and foreground
fg = cv2.imread(fg_path)
bg = cv2.imread(bg_path)

import matplotlib.pyplot as plt
plt.imshow(fg[...,::-1])
plt.show()
plt.imshow(bg[...,::-1])
plt.show()

# %% [markdown]
# ## Landmark Extraction
#
# To perform face swapping, first we need to localize face region. It can be achieved by detecting a face and its facial landmarks. Landmark prediction algorithm from dlib, used in this tutorial, provides 68 facial landmarks cover chin, eye, eybrows, nose and mouth regions.
#
# ![Face-Landmark-Representation.webp](data:image/webp;base64,...)

# %%
# Face Detector
detector = dlib.get_frontal_face_detector()
# Landmark Detector
predictor = openface.AlignDlib("/content/shape_predictor_68_face_landmarks.dat")

def predict_landmarks(img):
  dets = detector(img, 1)
  if len(dets) < 1:
    return None # Face Not Found
  
  print("Found %d faces" % len(dets))
  d = dets[0]
  gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  landmarks = predictor.findLandmarks(gray_img, d)
  return np.asarray(landmarks)

# %%
fg_landmarks = predict_landmarks(fg)
bg_landmarks = predict_landmarks(bg)
# Out:
# Found 1 faces
# Found 1 faces

# %%
def visualize_landmarks(img, landmarks, radius=2):
  new_img = np.copy(img)
  h, w, _ = new_img.shape
  for x, y in landmarks:
    x = int(x)
    y = int(y)
    new_img[max(0,y-radius):min(h-1,y+radius),max(0,x-radius):min(w-1,x+radius)] = (255, 0, 0)
  plt.imshow(new_img[...,::-1])
  plt.axis('off')
  plt.show()

# %% [markdown]
# If you don't see any blue points, increase the radius parameter.

# %%
visualize_landmarks(fg, fg_landmarks, radius=15)

# %%
visualize_landmarks(bg, bg_landmarks, radius=3)

# %% [markdown]
# **Exercise 1:** Face landmark detection is quite a challenging task on extreme boundary cases (with extreme pose, expression, or lighting). Try out with different images to evaluate the robustness of the landmark detection algorithm.

# %%
import glob
path = "/content/gdrive/MyDrive/Pictures Ass3 CV2 - possible/*.*"
for i, file in enumerate(glob.glob(path)):
  fg = cv2.imread(file)
  fg_landmarks = predict_landmarks(fg)
  visualize_landmarks(fg, fg_landmarks, radius=15)
# Out:
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces
# Found 1 faces

# %%
path = "/content/gdrive/MyDrive/Pictures Ass3 CV2 - not possible/*.*"
for file in glob.glob(path):
  fg = cv2.imread(file)
  visualize_landmarks(fg, [], radius=15)

# %% [markdown]
# ## Crop face images based on landmarks
#
# Given facial landmarks, face region and be localized and cropped.

# %%
from preprocess_img import Preprocess
from PIL import Image
from load_data import *

# read standard landmarks for preprocessing images
lm3D = load_lm3d()

def crop_image(img, landmarks):
  lm5 = np.zeros((5, 2), dtype=np.float32)
  lm5[0] = (landmarks[36] + landmarks[39]) / 2
  lm5[1] = (landmarks[42] + landmarks[45]) / 2
  lm5[2] = landmarks[30]
  lm5[3] = landmarks[48]
  lm5[4] = landmarks[54]
  input_img, lm_new, transform_params = Preprocess(Image.fromarray(img[...,::-1]), lm5, lm3D)

  return input_img, lm_new

# %%
fg_cropped, fg_cropped_lm = crop_image(fg, fg_landmarks)
bg_cropped, bg_cropped_lm = crop_image(bg, bg_landmarks)
# Out:
# /content/cv2_2021_assignment3/preprocess_img.py:19: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   k,_,_,_ = np.linalg.lstsq(A,b)
# /content/cv2_2021_assignment3/preprocess_img.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   trans_params = np.array([w0,h0,102.0/s,t[0],t[1]])

# %%
plt.imshow(fg_cropped[0, ..., ::-1])
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/cropped_fg", bbox_inches='tight')
plt.show()

plt.imshow(bg_cropped[0, ..., ::-1])
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/cropped_bg", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Naive face swapping implementation

# %% [markdown]
# One way to naively swap two faces is to detect the face region of the foreground image, crop it and put it on top of the background image.

# %%
fg_cropped_lm = predict_landmarks(fg_cropped[0]).astype(np.int32)

mask = np.zeros(fg_cropped[0].shape, dtype=np.uint8)
roi_corners = np.array([np.concatenate((fg_cropped_lm[:17], # chin
                                        fg_cropped_lm[17:27][::-1], # eyebrows
                                        ), axis=0)], dtype=np.int32)
channel_count = fg_cropped[0].shape[2]
ignore_mask_color = (255,)*channel_count
cv2.fillPoly(mask, roi_corners, ignore_mask_color)

plt.imshow(mask)
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/naive_mask", bbox_inches='tight')
plt.show()
# Out:
# Found 1 faces

# %%
swapped = np.where(mask, fg_cropped[0], bg_cropped[0])
plt.imshow(swapped[..., ::-1])
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/naive_swap", bbox_inches='tight')
plt.show()

# %% [markdown]
# **Face swap with 3D alignment**
#
# Now, if one can reconstruct a 3D model of two faces and determine their head pose and facial expression, expression and pose of the background face can be applied on the foreground face before merging them together.

# %%
from face_swap import FaceSwap
fs = FaceSwap()

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.13.1

# %% [markdown]
# Please ignore tensorflow errors if a swapped face is returned.

# %%
swapped = fs.swap(fg_cropped, bg_cropped)
# Out:
# 0.007932885 0.991364 0.065844 0.96091604
# CE (30762, 30730)
# Found polygon 551 edges
# CE (9547, 9667)
# Found polygon 78 edges
# solution 0, area 4.79062094
# solution 1, area 4.79041515
# solution 2, area 4.79041515
# solution 3, area 4.88589069
# solution 4, area 4.86822446
# solution 5, area 4.86822446
# solution 6, area 4.99695566
# solution 7, area 0.59468630
# solution 8, area 0.59468630
# solution 9, area 0.58488773
# solution 10, area 0.58330777
# solution 11, area 0.58326968
# solution 12, area 0.58326968
# solution 13, area 0.58355257
# solution 14, area 0.58885693
# solution 15, area 0.60444692
# solution 16, area 5.74373500
# solution 17, area 5.62663873
# solution 18, area 5.58337348
# solution 19, area 5.55091789
# solution 20, area 5.53081906
# solution 21, area 5.51701157
# solution 22, area 5.51701157
# solution 23, area 5.51703095
# solution 24, area 5.51710401
# solution 25, area 5.51731102
# solution 26, area 5.51041154
# solution 27, area 5.50720142
# solution 28, area 5.50720142
# solution 29, area 5.50721243
# solution 30, area 5.50721243
# solution 31, area 5.50742374
# solution 32, area 5.50073965
# solution 33, area 5.50001854
# solution 34, area 5.49988754
# solution 35, area 5.49983606
# solution 36, area 5.49983606
# solution 37, area 5.50018748
# solution 38, area 5.50072009
# solution 39, area 5.53107272
# solution 40, area 0.63431899
# solution 41, area 0.59723392
# solution 42, area 0.59062012
# solution 43, area 0.58686099
# solution 44, area 0.58471157
# solution 45, area 0.58315295
# solution 46, area 0.58277226
# solution 47, area 0.58264995
# solution 48, area 0.58264995
# solution 49, area 0.58294324
# solution 50, area 0.59291319
# solution 51, area 0.61926017
# solution 52, area 6.84943261
# solution 53, area 4.71575082
# solution 54, area 4.71575082
# solution 55, area 4.71587257
# solution 56, area 4.71140781
# solution 57, area 4.70626977
# solution 58, area 4.70626977
# solution 59, area 4.70631874
# solution 60, area 4.70642520
# solution 61, area 4.70687378
# solution 62, area 4.70779050
# solution 63, area 4.70670792
# solution 64, area 4.70670792
# solution 65, area 4.70679707
# solution 66, area 4.70709046
# solution 67, area 4.70754468
# solution 68, area 4.70826715
# solution 69, area 4.70819324
# solution 70, area 4.70819324
# solution 71, area 4.71523748
# solution 72, area 4.74576112
# solution 73, area 4.74520742
# solution 74, area 4.74492377
# solution 75, area 4.74480650
# solution 76, area 4.74480650
# solution 77, area 4.76329217
# WARNING:tensorflow:From /content/cv2_2021_assignment3/face_decoder.py:152: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_greater/Assert/AssertGuard/Merge' type=Merge>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()  File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()  File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()  File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-34-43889dea01b9>", line 1, in <module>
#     swapped = fs.swap(fg_cropped, bg_cropped)  File "/content/cv2_2021_assignment3/face_swap.py", line 147, in swap
#     texture_generator = TextureGenerator()  File "/content/cv2_2021_assignment3/face_swap.py", line 66, in __init__
#     self.fr0.Reconstruction_Block(self.new_coeff, None, self.texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 101, in Reconstruction_Block
#     texture_map, texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 342, in Render_block
#     far_clip = far_clip)  File "/content/cv2_2021_assignment3/texturing/mesh_renderer_texture.py", line 218, in mesh_renderer_texture
#     camera_up)  File "/usr/local/lib/python3.7/dist-packages/camera_utils.py", line 89, in look_at
#     message='Camera matrix is degenerate because eye and center are close.')  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/check_ops.py", line 943, in assert_greater
#     return control_flow_ops.Assert(condition, data, summarize=summarize)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_greater_1/Assert/AssertGuard/Merge' type=Merge>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()  File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()  File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()  File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-34-43889dea01b9>", line 1, in <module>
#     swapped = fs.swap(fg_cropped, bg_cropped)  File "/content/cv2_2021_assignment3/face_swap.py", line 147, in swap
#     texture_generator = TextureGenerator()  File "/content/cv2_2021_assignment3/face_swap.py", line 66, in __init__
#     self.fr0.Reconstruction_Block(self.new_coeff, None, self.texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 101, in Reconstruction_Block
#     texture_map, texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 342, in Render_block
#     far_clip = far_clip)  File "/content/cv2_2021_assignment3/texturing/mesh_renderer_texture.py", line 218, in mesh_renderer_texture
#     camera_up)  File "/usr/local/lib/python3.7/dist-packages/camera_utils.py", line 97, in look_at
#     message='Camera matrix is degenerate because up and gaze are close or'  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/check_ops.py", line 943, in assert_greater
#     return control_flow_ops.Assert(condition, data, summarize=summarize)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_greater_2/Assert/AssertGuard/Merge' type=Merge>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()  File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()  File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()  File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-34-43889dea01b9>", line 1, in <module>
#     swapped = fs.swap(fg_cropped, bg_cropped)  File "/content/cv2_2021_assignment3/face_swap.py", line 148, in swap
#     texture_renderer = TextureRenderer()  File "/content/cv2_2021_assignment3/face_swap.py", line 129, in __init__
#     self.fr0.Reconstruction_Block(self.new_coeff, texture_map, self.texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 101, in Reconstruction_Block
#     texture_map, texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 342, in Render_block
#     far_clip = far_clip)  File "/content/cv2_2021_assignment3/texturing/mesh_renderer_texture.py", line 218, in mesh_renderer_texture
#     camera_up)  File "/usr/local/lib/python3.7/dist-packages/camera_utils.py", line 89, in look_at
#     message='Camera matrix is degenerate because eye and center are close.')  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/check_ops.py", line 943, in assert_greater
#     return control_flow_ops.Assert(condition, data, summarize=summarize)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_greater_3/Assert/AssertGuard/Merge' type=Merge>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()  File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()  File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()  File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)  File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):  File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-34-43889dea01b9>", line 1, in <module>
#     swapped = fs.swap(fg_cropped, bg_cropped)  File "/content/cv2_2021_assignment3/face_swap.py", line 148, in swap
#     texture_renderer = TextureRenderer()  File "/content/cv2_2021_assignment3/face_swap.py", line 129, in __init__
#     self.fr0.Reconstruction_Block(self.new_coeff, texture_map, self.texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 101, in Reconstruction_Block
#     texture_map, texture_image, batchsize)  File "/content/cv2_2021_assignment3/face_decoder.py", line 342, in Render_block
#     far_clip = far_clip)  File "/content/cv2_2021_assignment3/texturing/mesh_renderer_texture.py", line 218, in mesh_renderer_texture
#     camera_up)  File "/usr/local/lib/python3.7/dist-packages/camera_utils.py", line 97, in look_at
#     message='Camera matrix is degenerate because up and gaze are close or'  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/check_ops.py", line 943, in assert_greater
#     return control_flow_ops.Assert(condition, data, summarize=summarize)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# reconstructing...
# Cache 3.402 secs
# Texture from cache 1.041 secs

# %%
plt.imshow(swapped)
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/dl_swapped2", bbox_inches='tight')
plt.show()

# %% [markdown]
# Now we can combine a swapped face with background.

# %%
mask = np.tile(np.any(swapped > 0, axis=2, keepdims=True), (1, 1, 3))

bg = np.copy(bg_cropped[0][..., ::-1])

# Sets all foreground pixel to 0
bg[mask] = 0

plt.imshow(bg)
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/dl_bg2", bbox_inches='tight')
plt.show()

# %%
output = np.where(mask, swapped, bg)

# %%
plt.imshow(output)
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/dl_swapped2", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Face Blending
#
# The final step of the face swapping pipeline is to blend swapped face with background.

# %%
def blend_imgs_bgr(source_img, target_img, mask):
    ## Your implementation of blending here

    mask = np.uint8(mask)
    height, width, _ = mask.shape

    blending_range = 4
    blending_mask = np.ones(mask.shape)
    for x in range(height):
      for y in range(width):
        area = mask[x-blending_range:x+blending_range, y-blending_range:y+blending_range,:]
        if np.any(area) and 0 in area:
          blending_mask[x-blending_range:x+blending_range, y-blending_range:y+blending_range,:] = 0

    blur_source = cv2.GaussianBlur(blending_mask, (51, 51), 0)
    blur_target = np.ones(mask.shape) - blur_source

    output = source_img/255 * blur_source + target_img/255 * blur_target
    return output

blended_face = blend_imgs_bgr(output[...,::-1], bg_cropped[0], mask)

plt.imshow(blended_face[...,::-1])
plt.axis("off")
plt.savefig(f"/content/gdrive/MyDrive/faceswaps/mm/dl_merged", bbox_inches='tight')
plt.show()
